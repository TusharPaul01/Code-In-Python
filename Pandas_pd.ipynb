# %% [markdown]
# <a href="https://colab.research.google.com/github/TusharPaul01/Code-In-Python/blob/main/Pandas_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

s = pd.Series([2,4,6,np.nan,8])
s
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    8.0
# dtype: float64

# %%
dates = pd.date_range("20230101", periods=6)

dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

df
# Out:
#                    A         B         C         D
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.D
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: D, dtype: int32

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.33536441, -0.66813827,  0.61213464,  1.66256352],
#        [-1.42973067, -0.32932163,  0.60090176,  0.28679523],
#        [-0.66404332, -0.1010437 ,  0.68716776, -0.48265732],
#        [-1.05918225, -0.06796362,  0.40759409, -0.20728631],
#        [-0.61722007, -1.47245214,  0.14925577, -0.96412088],
#        [-0.71952927, -0.32617829,  3.15067892, -1.57812399]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.804178 -0.494183  0.934622 -0.213805
# std    0.384158  0.525147  1.102911  1.119645
# min   -1.429731 -1.472452  0.149256 -1.578124
# 25%   -0.974269 -0.583434  0.455921 -0.843755
# 50%   -0.691786 -0.327750  0.606518 -0.344972
# 75%   -0.628926 -0.157327  0.668409  0.163275
# max   -0.335364 -0.067964  3.150679  1.662564

# %%
df.T  #transpose the data
# Out:
#    2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06
# A   -0.335364   -1.429731   -0.664043   -1.059182   -0.617220   -0.719529
# B   -0.668138   -0.329322   -0.101044   -0.067964   -1.472452   -0.326178
# C    0.612135    0.600902    0.687168    0.407594    0.149256    3.150679
# D    1.662564    0.286795   -0.482657   -0.207286   -0.964121   -1.578124

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2023-01-01  1.662564  0.612135 -0.668138 -0.335364
# 2023-01-02  0.286795  0.600902 -0.329322 -1.429731
# 2023-01-03 -0.482657  0.687168 -0.101044 -0.664043
# 2023-01-04 -0.207286  0.407594 -0.067964 -1.059182
# 2023-01-05 -0.964121  0.149256 -1.472452 -0.617220
# 2023-01-06 -1.578124  3.150679 -0.326178 -0.719529

# %%
df.head()
# Out:
#                    A         B         C         D
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286

# %%
df["A"]
# Out:
# 2023-01-01   -0.335364
# 2023-01-02   -1.429731
# 2023-01-03   -0.664043
# 2023-01-04   -1.059182
# 2023-01-05   -0.617220
# 2023-01-06   -0.719529
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657

# %%
df.loc[dates[0]]
# Out:
# A   -0.335364
# B   -0.668138
# C    0.612135
# D    1.662564
# Name: 2023-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2023-01-01 -0.335364 -0.668138
# 2023-01-02 -1.429731 -0.329322
# 2023-01-03 -0.664043 -0.101044
# 2023-01-04 -1.059182 -0.067964
# 2023-01-05 -0.617220 -1.472452
# 2023-01-06 -0.719529 -0.326178

# %%
df.iloc[[1, 2, 4], [0 , 2]]
# Out:
#                    A         C
# 2023-01-02 -1.429731  0.600902
# 2023-01-03 -0.664043  0.687168
# 2023-01-05 -0.617220  0.149256

# %%
df.iloc[1, 1]
# Out:
# -0.32932163244944357

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124

# %%
df[df["A"] > 0]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df[df > 0]
# Out:
#              A   B         C         D
# 2023-01-01 NaN NaN  0.612135  1.662564
# 2023-01-02 NaN NaN  0.600902  0.286795
# 2023-01-03 NaN NaN  0.687168       NaN
# 2023-01-04 NaN NaN  0.407594       NaN
# 2023-01-05 NaN NaN  0.149256       NaN
# 2023-01-06 NaN NaN  3.150679       NaN

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2023-01-01 -0.335364 -0.668138  0.612135  1.662564    one
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795    one
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657    two
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286  three
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121   four
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124  three

# %%
df.at[dates[0], "A"] = 0

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01  0.000000 -0.668138  0.612135  1.662564
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286
# 2023-01-05 -0.617220 -1.472452  0.149256 -0.964121
# 2023-01-06 -0.719529 -0.326178  3.150679 -1.578124

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C         D    E
# 2023-01-01  0.000000 -0.668138  0.612135  1.662564  1.0
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795  1.0
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657  NaN
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C         D    E
# 2023-01-01  0.000000 -0.668138  0.612135  1.662564  1.0
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C         D    E
# 2023-01-01  0.000000 -0.668138  0.612135  1.662564  1.0
# 2023-01-02 -1.429731 -0.329322  0.600902  0.286795  1.0
# 2023-01-03 -0.664043 -0.101044  0.687168 -0.482657  5.0
# 2023-01-04 -1.059182 -0.067964  0.407594 -0.207286  5.0
